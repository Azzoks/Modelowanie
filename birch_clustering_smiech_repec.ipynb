# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import Birch

# %%
data = load_iris(as_frame = True).frame

data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
model = Birch(branching_factor = 50, n_clusters = None, threshold = 1.5)

# %%
model.fit(data)
# Out:
# Birch(n_clusters=None, threshold=1.5)

# %%
pred = model.predict(data)

# %%
plt.scatter(data[:, 0], data[:, 1], c = pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c332f481d11f> in <cell line: 0>()
# ----> 1 plt.scatter(data[:, 0], data[:, 1], c = pred)
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import Birch
from sklearn.decomposition import PCA

# %%
iris = load_iris()
X = iris.data
y = iris.target


birch = Birch(n_clusters=3)  # n_clusters=3, ponieważ wiemy, że są 3 klasy w Iris
birch.fit(X)
labels = birch.labels_
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
# Wizualizacja klastrów
plt.figure(figsize=(8, 6))
for cluster in np.unique(labels):
    plt.scatter(X_pca[labels == cluster, 0], X_pca[labels == cluster, 1], label=f'Cluster {cluster}')

plt.title("BIRCH Clustering of Iris Dataset")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend()
plt.show()
